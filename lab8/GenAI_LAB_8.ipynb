# %%
# 🚀 Step 1: Install required libraries (Run this only once)
# !pip install langchain cohere langchain-community google-colab
# Out:
# Requirement already satisfied: langchain in /usr/local/lib/python3.12/dist-packages (0.3.28)
# Requirement already satisfied: cohere in /usr/local/lib/python3.12/dist-packages (6.0.0)
# Requirement already satisfied: langchain-community in /usr/local/lib/python3.12/dist-packages (0.3.27)
# Requirement already satisfied: google-colab in /usr/local/lib/python3.12/dist-packages (1.0.0)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.73 in /usr/local/lib/python3.12/dist-packages (from langchain) (0.3.84)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in /usr/local/lib/python3.12/dist-packages (from langchain) (0.3.11)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.17 in /usr/local/lib/python3.12/dist-packages (from langchain) (0.7.23)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain) (2.12.3)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain) (2.0.48)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from langchain) (2.32.4)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain) (6.0.3)
# Requirement already satisfied: fastavro<2.0.0,>=1.9.4 in /usr/local/lib/python3.12/dist-packages (from cohere) (1.12.1)
# Requirement already satisfied: httpx>=0.21.2 in /usr/local/lib/python3.12/dist-packages (from cohere) (0.28.1)
# Requirement already satisfied: pydantic-core<2.44.0,>=2.18.2 in /usr/local/lib/python3.12/dist-packages (from cohere) (2.41.4)
# Requirement already satisfied: tokenizers<1,>=0.15 in /usr/local/lib/python3.12/dist-packages (from cohere) (0.22.2)
# Requirement already satisfied: types-requests<3.0.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from cohere) (2.33.0.20260408)
# Requirement already satisfied: typing_extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from cohere) (4.15.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (3.13.4)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (9.1.4)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (2.13.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (2.0.2)
# Requirement already satisfied: google-auth==2.47.0 in /usr/local/lib/python3.12/dist-packages (from google-colab) (2.47.0)
# Requirement already satisfied: ipykernel==6.17.1 in /usr/local/lib/python3.12/dist-packages (from google-colab) (6.17.1)
# Requirement already satisfied: ipyparallel==8.8.0 in /usr/local/lib/python3.12/dist-packages (from google-colab) (8.8.0)
# Requirement already satisfied: ipython==7.34.0 in /usr/local/lib/python3.12/dist-packages (from google-colab) (7.34.0)
# Requirement already satisfied: pandas==2.2.2 in /usr/local/lib/python3.12/dist-packages (from google-colab) (2.2.2)
# Requirement already satisfied: jupyter-server==2.14.0 in /usr/local/lib/python3.12/dist-packages (from google-colab) (2.14.0)
# Requirement already satisfied: portpicker==1.5.2 in /usr/local/lib/python3.12/dist-packages (from google-colab) (1.5.2)
# Requirement already satisfied: tornado==6.5.1 in /usr/local/lib/python3.12/dist-packages (from google-colab) (6.5.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth==2.47.0->google-colab) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth==2.47.0->google-colab) (4.9.1)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel==6.17.1->google-colab) (1.8.15)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.12/dist-packages (from ipykernel==6.17.1->google-colab) (7.4.9)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel==6.17.1->google-colab) (0.2.1)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.12/dist-packages (from ipykernel==6.17.1->google-colab) (1.6.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from ipykernel==6.17.1->google-colab) (25.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from ipykernel==6.17.1->google-colab) (5.9.5)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.12/dist-packages (from ipykernel==6.17.1->google-colab) (26.2.1)
# Requirement already satisfied: traitlets>=5.1.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel==6.17.1->google-colab) (5.7.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipyparallel==8.8.0->google-colab) (4.4.2)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.12/dist-packages (from ipyparallel==8.8.0->google-colab) (0.4)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.12/dist-packages (from ipyparallel==8.8.0->google-colab) (2.9.0.post0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from ipyparallel==8.8.0->google-colab) (4.67.3)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.12/dist-packages (from ipython==7.34.0->google-colab) (75.2.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.12/dist-packages (from ipython==7.34.0->google-colab) (0.19.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython==7.34.0->google-colab) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython==7.34.0->google-colab) (3.0.52)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from ipython==7.34.0->google-colab) (2.20.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython==7.34.0->google-colab) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython==7.34.0->google-colab) (4.9.0)
# Requirement already satisfied: anyio>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server==2.14.0->google-colab) (4.13.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /usr/local/lib/python3.12/dist-packages (from jupyter-server==2.14.0->google-colab) (25.1.0)
# Requirement already satisfied: jinja2>=3.0.3 in /usr/local/lib/python3.12/dist-packages (from jupyter-server==2.14.0->google-colab) (3.1.6)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.12/dist-packages (from jupyter-server==2.14.0->google-colab) (5.9.1)
# Requirement already satisfied: jupyter-events>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server==2.14.0->google-colab) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-server==2.14.0->google-colab) (0.5.4)
# Requirement already satisfied: nbconvert>=6.4.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-server==2.14.0->google-colab) (7.17.0)
# Requirement already satisfied: nbformat>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server==2.14.0->google-colab) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server==2.14.0->google-colab) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /usr/local/lib/python3.12/dist-packages (from jupyter-server==2.14.0->google-colab) (0.24.1)
# Requirement already satisfied: send2trash>=1.8.2 in /usr/local/lib/python3.12/dist-packages (from jupyter-server==2.14.0->google-colab) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.12/dist-packages (from jupyter-server==2.14.0->google-colab) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /usr/local/lib/python3.12/dist-packages (from jupyter-server==2.14.0->google-colab) (1.9.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas==2.2.2->google-colab) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas==2.2.2->google-colab) (2025.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.0.0->langchain) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.0.0->langchain) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.0.0->langchain) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.0.0->langchain) (2026.2.25)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.23.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.12/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.21.2->cohere) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx>=0.21.2->cohere) (0.16.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<1.0.0,>=0.3.73->langchain) (1.33)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<1.0.0,>=0.3.73->langchain) (0.14.1)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.17->langchain) (3.11.8)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.17->langchain) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.17->langchain) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (1.2.2)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain) (3.3.2)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in /usr/local/lib/python3.12/dist-packages (from tokenizers<1,>=0.15->cohere) (1.8.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.12/dist-packages (from argon2-cffi>=21.1->jupyter-server==2.14.0->google-colab) (25.1.0)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.15->cohere) (3.25.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.15->cohere) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.15->cohere) (1.4.2)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.15->cohere) (0.24.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython==7.34.0->google-colab) (0.8.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2>=3.0.3->jupyter-server==2.14.0->google-colab) (3.0.3)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<1.0.0,>=0.3.73->langchain) (3.1.1)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server==2.14.0->google-colab) (4.9.4)
# Requirement already satisfied: jsonschema>=4.18.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server==2.14.0->google-colab) (4.26.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server==2.14.0->google-colab) (4.1.0)
# Requirement already satisfied: referencing in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server==2.14.0->google-colab) (0.37.0)
# Requirement already satisfied: rfc3339-validator in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server==2.14.0->google-colab) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server==2.14.0->google-colab) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.4.4->jupyter-server==2.14.0->google-colab) (4.13.5)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server==2.14.0->google-colab) (6.3.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.4.4->jupyter-server==2.14.0->google-colab) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.4.4->jupyter-server==2.14.0->google-colab) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.4.4->jupyter-server==2.14.0->google-colab) (3.2.0)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.4.4->jupyter-server==2.14.0->google-colab) (0.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.4.4->jupyter-server==2.14.0->google-colab) (1.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.12/dist-packages (from nbformat>=5.3.0->jupyter-server==2.14.0->google-colab) (2.21.2)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython==7.34.0->google-colab) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython==7.34.0->google-colab) (0.6.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth==2.47.0->google-colab) (0.6.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.1->ipyparallel==8.8.0->google-colab) (1.17.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.1.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server==2.14.0->google-colab) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server==2.14.0->google-colab) (1.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.18.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server==2.14.0->google-colab) (2025.9.1)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.18.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server==2.14.0->google-colab) (0.30.0)
# Requirement already satisfied: fqdn in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server==2.14.0->google-colab) (1.5.1)
# Requirement already satisfied: isoduration in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server==2.14.0->google-colab) (20.11.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server==2.14.0->google-colab) (1.1.0)
# Requirement already satisfied: uri-template in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server==2.14.0->google-colab) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server==2.14.0->google-colab) (25.10.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server==2.14.0->google-colab) (2.0.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server==2.14.0->google-colab) (2.8.3)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.15->cohere) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.15->cohere) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.15->cohere) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.15->cohere) (0.0.4)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server==2.14.0->google-colab) (3.0)
# Requirement already satisfied: lark>=1.2.2 in /usr/local/lib/python3.12/dist-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server==2.14.0->google-colab) (1.3.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.15->cohere) (4.0.0)
# Requirement already satisfied: arrow>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server==2.14.0->google-colab) (1.4.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.15->cohere) (0.1.2)

# %%
# Explicitly install langchain-cohere
# !pip install langchain-cohere
# Out:
# Collecting langchain-cohere
#   Downloading langchain_cohere-0.5.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting cohere<6.0,>=5.18.0 (from langchain-cohere)
#   Using cached cohere-5.21.1-py3-none-any.whl.metadata (3.6 kB)
# Collecting langchain-community<0.5.0,>=0.4.0 (from langchain-cohere)
#   Using cached langchain_community-0.4.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting langchain-core<2.0,>=1.0.0 (from langchain-cohere)
#   Downloading langchain_core-1.2.28-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: pydantic<3,>=2 in /usr/local/lib/python3.12/dist-packages (from langchain-cohere) (2.12.3)
# Collecting types-pyyaml<7.0.0.0,>=6.0.12.20240917 (from langchain-cohere)
#   Downloading types_pyyaml-6.0.12.20260408-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: fastavro<2.0.0,>=1.9.4 in /usr/local/lib/python3.12/dist-packages (from cohere<6.0,>=5.18.0->langchain-cohere) (1.12.1)
# Requirement already satisfied: httpx>=0.21.2 in /usr/local/lib/python3.12/dist-packages (from cohere<6.0,>=5.18.0->langchain-cohere) (0.28.1)
# Requirement already satisfied: pydantic-core>=2.18.2 in /usr/local/lib/python3.12/dist-packages (from cohere<6.0,>=5.18.0->langchain-cohere) (2.41.4)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from cohere<6.0,>=5.18.0->langchain-cohere) (2.32.4)
# Requirement already satisfied: tokenizers<1,>=0.15 in /usr/local/lib/python3.12/dist-packages (from cohere<6.0,>=5.18.0->langchain-cohere) (0.22.2)
# Requirement already satisfied: types-requests<3.0.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from cohere<6.0,>=5.18.0->langchain-cohere) (2.33.0.20260408)
# Requirement already satisfied: typing_extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from cohere<6.0,>=5.18.0->langchain-cohere) (4.15.0)
# Collecting langchain-classic<2.0.0,>=1.0.0 (from langchain-community<0.5.0,>=0.4.0->langchain-cohere)
#   Using cached langchain_classic-1.0.3-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community<0.5.0,>=0.4.0->langchain-cohere) (2.0.48)
# Collecting requests<3.0.0,>=2.0.0 (from cohere<6.0,>=5.18.0->langchain-cohere)
#   Using cached requests-2.33.1-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community<0.5.0,>=0.4.0->langchain-cohere) (6.0.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.12/dist-packages (from langchain-community<0.5.0,>=0.4.0->langchain-cohere) (3.13.4)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community<0.5.0,>=0.4.0->langchain-cohere) (9.1.4)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in /usr/local/lib/python3.12/dist-packages (from langchain-community<0.5.0,>=0.4.0->langchain-cohere) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /usr/local/lib/python3.12/dist-packages (from langchain-community<0.5.0,>=0.4.0->langchain-cohere) (2.13.1)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in /usr/local/lib/python3.12/dist-packages (from langchain-community<0.5.0,>=0.4.0->langchain-cohere) (0.7.23)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community<0.5.0,>=0.4.0->langchain-cohere) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in /usr/local/lib/python3.12/dist-packages (from langchain-community<0.5.0,>=0.4.0->langchain-cohere) (2.0.2)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0,>=1.0.0->langchain-cohere) (1.33)
# Requirement already satisfied: packaging>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0,>=1.0.0->langchain-cohere) (25.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0,>=1.0.0->langchain-cohere) (0.14.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2->langchain-cohere) (0.7.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2->langchain-cohere) (0.4.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.5.0,>=0.4.0->langchain-cohere) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.5.0,>=0.4.0->langchain-cohere) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.5.0,>=0.4.0->langchain-cohere) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.5.0,>=0.4.0->langchain-cohere) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.5.0,>=0.4.0->langchain-cohere) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.5.0,>=0.4.0->langchain-cohere) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.5.0,>=0.4.0->langchain-cohere) (1.23.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.12/dist-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community<0.5.0,>=0.4.0->langchain-cohere) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community<0.5.0,>=0.4.0->langchain-cohere) (0.9.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx>=0.21.2->cohere<6.0,>=5.18.0->langchain-cohere) (4.13.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx>=0.21.2->cohere<6.0,>=5.18.0->langchain-cohere) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.21.2->cohere<6.0,>=5.18.0->langchain-cohere) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx>=0.21.2->cohere<6.0,>=5.18.0->langchain-cohere) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx>=0.21.2->cohere<6.0,>=5.18.0->langchain-cohere) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0,>=1.0.0->langchain-cohere) (3.1.1)
# Collecting langchain-text-splitters<2.0.0,>=1.1.1 (from langchain-classic<2.0.0,>=1.0.0->langchain-community<0.5.0,>=0.4.0->langchain-cohere)
#   Downloading langchain_text_splitters-1.1.1-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community<0.5.0,>=0.4.0->langchain-cohere) (3.11.8)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community<0.5.0,>=0.4.0->langchain-cohere) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community<0.5.0,>=0.4.0->langchain-cohere) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community<0.5.0,>=0.4.0->langchain-cohere) (0.25.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community<0.5.0,>=0.4.0->langchain-cohere) (1.2.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.0.0->cohere<6.0,>=5.18.0->langchain-cohere) (3.4.6)
# Requirement already satisfied: urllib3<3,>=1.26 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.0.0->cohere<6.0,>=5.18.0->langchain-cohere) (2.5.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community<0.5.0,>=0.4.0->langchain-cohere) (3.3.2)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in /usr/local/lib/python3.12/dist-packages (from tokenizers<1,>=0.15->cohere<6.0,>=5.18.0->langchain-cohere) (1.8.0)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.15->cohere<6.0,>=5.18.0->langchain-cohere) (3.25.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.15->cohere<6.0,>=5.18.0->langchain-cohere) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.15->cohere<6.0,>=5.18.0->langchain-cohere) (1.4.2)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.15->cohere<6.0,>=5.18.0->langchain-cohere) (4.67.3)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.15->cohere<6.0,>=5.18.0->langchain-cohere) (0.24.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community<0.5.0,>=0.4.0->langchain-cohere) (1.1.0)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.15->cohere<6.0,>=5.18.0->langchain-cohere) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.15->cohere<6.0,>=5.18.0->langchain-cohere) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.15->cohere<6.0,>=5.18.0->langchain-cohere) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.15->cohere<6.0,>=5.18.0->langchain-cohere) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.15->cohere<6.0,>=5.18.0->langchain-cohere) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.15->cohere<6.0,>=5.18.0->langchain-cohere) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.15->cohere<6.0,>=5.18.0->langchain-cohere) (0.1.2)
# Downloading langchain_cohere-0.5.0-py3-none-any.whl (42 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 kB 2.2 MB/s eta 0:00:00
# Downloading cohere-5.21.1-py3-none-any.whl (334 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 334.3/334.3 kB 13.6 MB/s eta 0:00:00
# Downloading langchain_community-0.4.1-py3-none-any.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 65.5 MB/s eta 0:00:00
# Downloading langchain_core-1.2.28-py3-none-any.whl (508 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 508.7/508.7 kB 28.0 MB/s eta 0:00:00
# Downloading types_pyyaml-6.0.12.20260408-py3-none-any.whl (20 kB)
# Downloading langchain_classic-1.0.3-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 42.2 MB/s eta 0:00:00
# Downloading requests-2.33.1-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 4.8 MB/s eta 0:00:00
# Downloading langchain_text_splitters-1.1.1-py3-none-any.whl (35 kB)
# Installing collected packages: types-pyyaml, requests, langchain-core, langchain-text-splitters, langchain-classic, cohere, langchain-community, langchain-cohere
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.3.84
#     Uninstalling langchain-core-0.3.84:
#       Successfully uninstalled langchain-core-0.3.84
#   Attempting uninstall: langchain-text-splitters
#     Found existing installation: langchain-text-splitters 0.3.11
#     Uninstalling langchain-text-splitters-0.3.11:
#       Successfully uninstalled langchain-text-splitters-0.3.11
#   Attempting uninstall: cohere
#     Found existing installation: cohere 6.0.0
#     Uninstalling cohere-6.0.0:
#       Successfully uninstalled cohere-6.0.0
#   Attempting uninstall: langchain-community
#     Found existing installation: langchain-community 0.3.27
#     Uninstalling langchain-community-0.3.27:
#       Successfully uninstalled langchain-community-0.3.27
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain 0.3.28 requires langchain-core<1.0.0,>=0.3.73, but you have langchain-core 1.2.28 which is incompatible.
# langchain 0.3.28 requires langchain-text-splitters<1.0.0,>=0.3.9, but you have langchain-text-splitters 1.1.1 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.33.1 which is incompatible.
# Successfully installed cohere-5.21.1 langchain-classic-1.0.3 langchain-cohere-0.5.0 langchain-community-0.4.1 langchain-core-1.2.28 langchain-text-splitters-1.1.1 requests-2.33.1 types-pyyaml-6.0.12.20260408

# %%
# 🚀 Step 2: Import necessary libraries
import cohere
import getpass
from langchain import PromptTemplate
from langchain_cohere import ChatCohere
from langchain_core.messages import HumanMessage
from google.colab import auth
from google.colab import drive

# %%
# 🚀 Step 3: Authenticate Google Drive
auth.authenticate_user()
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# 🚀 Step 4: Load the Text File from Google Drive
file_path = "/content/drive/MyDrive/Classroom/6th Sem January 2026/GenAI/LAB - 8/AIOverview.txt" # Change this to your file path

# %%
try:
  with open(file_path, "r", encoding="utf-8") as file:
    text_content = file.read()
  print("✅ File loaded successfully!")
except Exception as e:
  print("❌ Error loading file:", str(e))
# Out:
# ✅ File loaded successfully!

# %%
# 🚀 Step 5: Set Up Cohere API Key
COHERE_API_KEY = getpass.getpass("🔑 Enter your Cohere API Key: ")
# Out:
# 🔑 Enter your Cohere API Key: ··········

# %%
# 🚀 Step 6: Initialize Cohere Model with LangChain
cohere_llm = ChatCohere(cohere_api_key=COHERE_API_KEY, model="command-a-03-2025")

# %%
# 🚀 Step 7: Create a Prompt Template
template = """
You are an AI assistant helping to summarize and analyze a text document.
Here is the document content:
{text}
🔹 Summary:
- Provide a concise summary of the document.
🔹 Key Takeaways:
- List 3 important points from the text.
🔹 Sentiment Analysis:
- Determine if the sentiment of the document is Positive, Negative, or Neutral.
"""

# %%
prompt_template = PromptTemplate(input_variables=["text"], template=template)

# %%
# 🚀 Step 8: Format the Prompt and Generate Output
formatted_prompt = prompt_template.format(text=text_content)

# %%
print("formatted_prompt := ",formatted_prompt)
# Out:
# formatted_prompt :=
# You are an AI assistant helping to summarize and analyze a text document.
# Here is the document content:
# AI Overview
# Agentic AI refers to autonomous systems capable of pursuing complex goals with minimal human oversight by planning, reasoning, and using tools. Unlike generative AI that produces content, agentic AI acts to complete multi-step tasks. It leverages Large Language Models (LLMs) to make decisions, adapt to environments, and iteratively improve performance.
# IBM
# IBM
#  +3
# Key Characteristics of Agentic AI
# Autonomy: Agents operate independently, deciding on the best course of action to achieve a goal rather than following rigid, pre-programmed steps.
# Goal-Driven Reasoning: Systems break down high-level objectives into actionable sub-tasks.
# Adaptability & Learning: Agents learn from interactions and feedback, allowing them to adjust strategies in real time.
# Tool Usage: They can interact with external software, databases, and APIs to gather information or execute tasks.
# Google Cloud
# Google Cloud
#  +3
# Core Components
# Brain (LLM): Provides reasoning, planning, and decision-making capabilities.
# Memory: Stores past actions and outcomes for context-aware decisions.
# Tools: Interfaces enabling action (e.g., browsing the web, running code, sending emails).
# Planning: Breaking down complex objectives into a sequence of steps.
# Google Cloud
# Google Cloud
#  +4
# Agentic AI vs. Traditional AI
# Traditional/Generative AI: "Input
#  Output" (e.g., Summarize this document).
# Agentic AI: "Goal
#  Plan
#  Act
#  Evaluate
#  Goal" (e.g., Research this topic, write a report, and email it to my team).
# Automation Anywhere
# Automation Anywhere
#  +4
# Examples and Applications
# Customer Service: Agents that not only answer questions but also process returns or update accounts by accessing multiple systems.
# Financial Services: Automating complex workflows like fraud detection, compliance checks, and personalized financial planning.
# Personal Assistants: Agents that can manage calendars, book travel, and coordinate schedules independently.
# Multi-Agent Systems: Specialized agents collaborating on a single project (e.g., one agent writes code, another tests it).
# IBM
# IBM
#  +4
# Benefits
# Agentic AI increases operational efficiency by automating complex, multi-step workflows at scale, leading to higher accuracy in decision-making and reduced need for human-in-the-loop intervention.
# SAP Learning
# SAP Learning
#  +1
# 🔹 Summary:
# - Provide a concise summary of the document.
# 🔹 Key Takeaways:
# - List 3 important points from the text.
# 🔹 Sentiment Analysis:
# - Determine if the sentiment of the document is Positive, Negative, or Neutral.

# %%
# 🚀 Step 8: Format the Prompt and Generate Output
formatted_prompt = prompt_template.format(text=text_content)

# %%
response = cohere_llm.invoke([HumanMessage(content=formatted_prompt)]).content
# 🚀 Step 9: Display the Generated Output
print("\n📌 **Formatted Output** 📌")
print(response)
# Out:
# 📌 **Formatted Output** 📌
# ### **Summary:**
# Agentic AI refers to autonomous systems that pursue complex goals with minimal human oversight by planning, reasoning, and using tools. Unlike generative AI, which produces content, agentic AI focuses on completing multi-step tasks. It leverages Large Language Models (LLMs) for decision-making, adapts to environments, and iteratively improves performance. Key characteristics include autonomy, goal-driven reasoning, adaptability, and tool usage. Core components are the LLM (brain), memory, tools, and planning. Applications span customer service, financial services, personal assistants, and multi-agent systems. Agentic AI enhances operational efficiency, accuracy, and reduces the need for human intervention.
#
# ---
#
# ### **Key Takeaways:**
# 1. **Autonomy and Goal-Driven Reasoning:** Agentic AI operates independently, breaking down high-level objectives into actionable sub-tasks without rigid pre-programming.
# 2. **Adaptability and Tool Usage:** Agents learn from interactions, adjust strategies in real time, and interact with external tools like software, databases, and APIs.
# 3. **Operational Efficiency:** Agentic AI automates complex workflows, improves decision-making accuracy, and reduces reliance on human intervention.
#
# ---
#
# ### **Sentiment Analysis:**
# **Positive.** The document highlights the capabilities, benefits, and applications of agentic AI in a favorable light, emphasizing its potential to enhance efficiency, accuracy, and autonomy in various domains. There are no negative remarks or criticisms present.
